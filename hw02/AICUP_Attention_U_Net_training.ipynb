# %% [markdown]
# ![投影片11.PNG](data:image/png;base64,...)

# %% [markdown]
# # 1. 環境設定

# %%
import sys
# !{sys.executable} --version
# !{sys.executable} -m pip install -U numpy==1.26.4
import os
os._exit(0)
# Out:
# Python 3.11.13
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %%
import sys
# !{sys.executable} -m pip install -U ray==2.5.0
import ray
print(ray.__version__)
# Out:
# Collecting ray==2.5.0
#   Downloading ray-2.5.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (25.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (4.24.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.4.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (2.32.3)
# Collecting grpcio<=1.51.3,>=1.42.0 (from ray==2.5.0)
#   Downloading grpcio-1.51.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal->ray==2.5.0) (4.14.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (2025.7.14)
# Downloading ray-2.5.0-cp311-cp311-manylinux2014_x86_64.whl (56.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 22.0 MB/s eta 0:00:00
# Downloading grpcio-1.51.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 78.8 MB/s eta 0:00:00
# Installing collected packages: grpcio, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.73.1
#     Uninstalling grpcio-1.73.1:
#       Successfully uninstalled grpcio-1.73.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires grpcio>=1.71.2, but you have grpcio 1.51.3 which is incompatible.
# Successfully installed grpcio-1.51.3 ray-2.5.0
# 2.5.0

# %%
import sys
# !{sys.executable} -m pip install -U monai==1.2.0
import monai
print(monai.__version__)
# Out:
# Collecting monai==1.2.0
#   Downloading monai-1.2.0-202306081546-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.11/dist-packages (from monai==1.2.0) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from monai==1.2.0) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9->monai==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9->monai==1.2.0) (3.0.2)
# Downloading monai-1.2.0-202306081546-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 113.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 76.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 21.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, monai
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed monai-1.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# 1.2.0

# %%
# !pip install -U ml_collections
# Out:
# Collecting ml_collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from ml_collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from ml_collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: ml_collections
# Successfully installed ml_collections-1.1.0

# %%
# !git clone https://github.com/kairaun/Sam.git
# Out:
# Cloning into 'Sam'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd ./Sam
! ls
! head pyproject.toml
# !pip install -e .
import os
os._exit(0)
# Out:
# [Errno 2] No such file or directory: './Sam'
# /root/ray_results/default
# head: cannot open 'pyproject.toml' for reading: No such file or directory
# Obtaining file:///root/ray_results/default
# ERROR: file:///root/ray_results/default does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import sys
# !{sys.executable} -m pip install -U --no-deps monailabel
import monailabel
print(monailabel.__version__)
# Out:
# Collecting monailabel
#   Downloading monailabel-0.8.5-202411252313-py3-none-any.whl.metadata (23 kB)
# Downloading monailabel-0.8.5-202411252313-py3-none-any.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 92.7 MB/s eta 0:00:00
# Installing collected packages: monailabel
# Successfully installed monailabel-0.8.5
# 0.8.5

# %%
# !pip install "pydantic<2.0"
# Out:
# Collecting pydantic<2.0
#   Downloading pydantic-1.10.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.0) (4.14.1)
# Downloading pydantic-1.10.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 61.8 MB/s eta 0:00:00
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.7
#     Uninstalling pydantic-2.11.7:
#       Successfully uninstalled pydantic-2.11.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# monailabel 0.8.5 requires bcrypt>=4.1.2, which is not installed.
# monailabel 0.8.5 requires dicomweb-client[gcp]>=0.59.1, which is not installed.
# monailabel 0.8.5 requires expiring_dict>=1.1.0, which is not installed.
# monailabel 0.8.5 requires expiringdict>=1.2.2, which is not installed.
# monailabel 0.8.5 requires girder-client>=3.2.3, which is not installed.
# monailabel 0.8.5 requires ninja>=1.11.1.1, which is not installed.
# monailabel 0.8.5 requires numpymaxflow>=0.0.7, which is not installed.
# monailabel 0.8.5 requires passlib>=1.7.4, which is not installed.
# monailabel 0.8.5 requires pydantic-settings>=2.2.1, which is not installed.
# monailabel 0.8.5 requires pydicom>=2.4.4, which is not installed.
# monailabel 0.8.5 requires pydicom-seg>=0.4.1, which is not installed.
# monailabel 0.8.5 requires pynetdicom>=2.0.2, which is not installed.
# monailabel 0.8.5 requires pynrrd>=1.0.0, which is not installed.
# monailabel 0.8.5 requires python-dotenv>=1.0.1, which is not installed.
# monailabel 0.8.5 requires sam2>=0.4.1; python_version >= "3.10", which is not installed.
# monailabel 0.8.5 requires schedule>=1.2.1, which is not installed.
# monailabel 0.8.5 requires timeloop>=1.0.2, which is not installed.
# monailabel 0.8.5 requires watchdog>=4.0.0, which is not installed.
# monailabel 0.8.5 requires monai[fire,gdown,ignite,itk,lmdb,mlflow,nibabel,openslide,pillow,psutil,skimage,tensorboard,torchvision,tqdm]>=1.4.0, but you have monai 1.2.0 which is incompatible.
# monailabel 0.8.5 requires pydantic>=2.7.0, but you have pydantic 1.10.24 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.24 which is incompatible.
# google-genai 1.25.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.24 which is incompatible.
# gradio 5.31.0 requires pydantic<2.12,>=2.0, but you have pydantic 1.10.24 which is incompatible.
# langchain 0.3.26 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.24 which is incompatible.
# langchain-core 0.3.68 requires pydantic>=2.7.4, but you have pydantic 1.10.24 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.24 which is incompatible.
# Successfully installed pydantic-1.10.24

# %%
# Clone the project
# !git clone https://github.com/kairaun/CardiacSegV2.git
# Out:
# Cloning into 'CardiacSegV2'...
# remote: Enumerating objects: 641, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 641 (delta 24), reused 8 (delta 8), pack-reused 610 (from 2)
# Receiving objects: 100% (641/641), 17.33 MiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %%
# Install the Environment
! sudo chmod 700 /content/CardiacSegV2/setup.sh
! /content/CardiacSegV2/setup.sh
! pip install gdown==4.6.0
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.2 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,143 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,457 kB]
# Get:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [44.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,595 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,982 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,861 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,181 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,530 kB]
# Get:22 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,827 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:26 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Fetched 37.7 MB in 6s (6,840 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 184 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.3-1build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 184 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1+cu113 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for torch==1.12.1+cu113
# Collecting gdown==4.6.0
#   Downloading gdown-4.6.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==4.6.0) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==4.6.0) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (1.7.1)
# Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# Successfully installed gdown-4.6.0

# %%
# Modify the code
! sed -i '8c \\    os.makedirs(\"/content/CardiacSegV2/\"+data_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '20c \\        os.makedirs(\"/content/CardiacSegV2/\"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '29c \\        os.makedirs("/content/CardiacSegV2/"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/infer.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/tune.py
! sed -i '36c ray.init(runtime_env={\"working_dir\": \"/content/CardiacSegV2\"})' /content/CardiacSegV2/expers/tune.py

# %%
! python /content/CardiacSegV2/setup_dir.py
# Out:
# mkdir data: dataset/chgh
# mkdir exp: exps/exps/attention_unet/chgh/tune_results

# %% [markdown]
# ![投影片12.PNG](data:image/png;base64,...)

# %% [markdown]
# ![投影片13.PNG](data:image/png;base64,...)

# %% [markdown]
# # 下載訓練資料集

# %% [markdown]
# 9/27更新
# 如果可以的話，請將資料集上傳到自己的google drive再修改下面的code上傳到colab內，最近發現google drive有鎖到我們放置資料的帳號的這個位置，謝謝

# %%
# !ls
# Out:
# ray_results

# %%
import gdown
import os
#下載ct、gt

# 請先將下載的training_image1 2 3和training_label內的全部資料包裝壓縮成zip檔後再上傳至自己的google drive上
# https://drive.google.com/file/d/1LOSFSmdCQMcbzrsDxEmqkWguRv5K4OqQ/view?usp=sharing
# 請在[位置id]處放上你的訓練集檔案位置

gdown.download("https://drive.google.com/u/0/uc?id=1N502H_Q87ywG0YvdJ1WqiSe-kMeUtANA&export=download","/content/CardiacSegV2/dataset/chgh/AICUP_training.zip")
! unzip "/content/CardiacSegV2/dataset/chgh/AICUP_training.zip" -d "/content/CardiacSegV2/dataset/chgh/"
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1N502H_Q87ywG0YvdJ1WqiSe-kMeUtANA&export=download
# To: /content/CardiacSegV2/dataset/chgh/AICUP_training.zip
# 100%|██████████| 5.32G/5.32G [01:06<00:00, 79.9MB/s]
# Archive:  /content/CardiacSegV2/dataset/chgh/AICUP_training.zip
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0047.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0047_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0048.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0048_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0049.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0049_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0050.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0050_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0001.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0001_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0002.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0002_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0003.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0003_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0004.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0004_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0005.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0005_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0006.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0006_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0007.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0007_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0008.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0008_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0009.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0009_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0010.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0010_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0011.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0011_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0012.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0012_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0013.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0013_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0014.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0014_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0015.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0015_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0016.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0016_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0017.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0017_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0018.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0018_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0019.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0019_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0020.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0020_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0021.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0021_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0022.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0022_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0023.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0023_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0024.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0024_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0025.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0025_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0026.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0026_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0027.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0027_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0028.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0028_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0029.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0029_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0030.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0030_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0031.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0031_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0032.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0032_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0033.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0033_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0034.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0034_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0035.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0035_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0036.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0036_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0037.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0037_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0038.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0038_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0039.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0039_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0040.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0040_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0041.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0041_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0042.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0042_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0043.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0043_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0044.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0044_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0045.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0045_gt.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0046.nii.gz
#   inflating: /content/CardiacSegV2/dataset/chgh/patient0046_gt.nii.gz

# %% [markdown]
# 設定路徑

# %%
import os

workspace_dir = '/content/CardiacSegV2'
model_name = 'attention_unet' #unet3d attention_unet cotr unetr swinunetr unetcnx_a1 testnet
data_name = 'chgh'
exp_name = 'AICUP_training'
data_dict_file_name = 'AICUP_training.json'

# set exp dir
root_exp_dir = os.path.join(workspace_dir,'exps','exps',model_name,data_name,'tune_results')

# set data dir
root_data_dir = os.path.join(workspace_dir,'dataset',data_name)
data_dir = os.path.join(root_data_dir)
# data dict json path
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# set model, log, eval dir
model_dir = os.path.join('./', 'models')
log_dir = os.path.join('./', 'logs')
eval_dir = os.path.join('./', 'evals')
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)


# model path
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# mkdir root exp dir
os.makedirs(root_exp_dir, exist_ok=True)

# %% [markdown]
# ![投影片14.PNG](data:image/png;base64,...)

# %% [markdown]
# 正式訓練
#
# ->已從hd95改成iou

# %%
# training
# !python /content/CardiacSegV2/expers/tune.py \
--tune_mode="train" \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=5 \
--max_early_stop_count=2 \
--max_epoch=20  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=4 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-42 \
--a_max=423 \
--space_x=0.7 \
--space_y=0.7 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=120 \
--optim="AdamW" \
--lr=5e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process
# Out:
# 2025-11-16 14:03:22.487106: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763301802.532154    4923 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763301802.543847    4923 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-16 14:03:22.567096: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# 2025-11-16 14:03:49,886	INFO worker.py:1636 -- Started a local Ray instance.
# 2025-11-16 14:03:50,765	INFO packaging.py:520 -- Creating a file package for local directory '/content/CardiacSegV2'.
# 2025-11-16 14:03:50,790	WARNING packaging.py:394 -- File /content/CardiacSegV2/.git/objects/pack/pack-e31abb332b17f9926c99906971b191c247ca92a0.pack is very large (17.33MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['/content/CardiacSegV2/.git/objects/pack/pack-e31abb332b17f9926c99906971b191c247ca92a0.pack']})`
# 2025-11-16 14:03:51,272	INFO packaging.py:347 -- Pushing file package 'gcs://_ray_pkg_ffdb4ca273214716.zip' (37.60MiB) to Ray cluster...
# 2025-11-16 14:03:51,439	INFO packaging.py:360 -- Successfully pushed file package 'gcs://_ray_pkg_ffdb4ca273214716.zip'.
# /usr/local/lib/python3.11/dist-packages/ray/air/config.py:799: UserWarning: Setting a `RunConfig.local_dir` is deprecated and will be removed in the future. If you are not using remote storage,set the `RunConfig.storage_path` instead. Otherwise, set the`RAY_AIR_LOCAL_CACHE_DIR` environment variable to control the local cache location.
#   warnings.warn(
# 2025-11-16 14:03:54,284	INFO tensorboardx.py:178 -- pip install "ray[tune]" to see TensorBoard files.
# 2025-11-16 14:03:54,284	WARNING callback.py:144 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2025-11-16 14:03:54 (running for 00:00:00.29)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/2 CPUs, 0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 PENDING)
# +------------------+----------+-------+----------------------+
# | Trial name       | status   | loc   | exp                  |
# |------------------+----------+-------+----------------------|
# | main_1625c_00000 | PENDING  |       | {'exp': 'AICUP__6940 |
# +------------------+----------+-------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:03:59 (running for 00:00:05.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 PENDING)
# +------------------+----------+-------+----------------------+
# | Trial name       | status   | loc   | exp                  |
# |------------------+----------+-------+----------------------|
# | main_1625c_00000 | PENDING  |       | {'exp': 'AICUP__6940 |
# +------------------+----------+-------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:04 (running for 00:00:10.32)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 PENDING)
# +------------------+----------+-------+----------------------+
# | Trial name       | status   | loc   | exp                  |
# |------------------+----------+-------+----------------------|
# | main_1625c_00000 | PENDING  |       | {'exp': 'AICUP__6940 |
# +------------------+----------+-------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:09 (running for 00:00:15.36)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 PENDING)
# +------------------+----------+-------+----------------------+
# | Trial name       | status   | loc   | exp                  |
# |------------------+----------+-------+----------------------|
# | main_1625c_00000 | PENDING  |       | {'exp': 'AICUP__6940 |
# +------------------+----------+-------+----------------------+
#
#
# (pid=5317) 2025-11-16 14:04:09.676707: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=5317) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=5317) E0000 00:00:1763301849.715430    5317 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=5317) E0000 00:00:1763301849.727113    5317 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=5317) /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# (pid=5317)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# (pid=5317) /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# (pid=5317)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# (func pid=5317) a_max 423.0
# (func pid=5317) a_min -42.0
# (func pid=5317) space_x 0.7
# (func pid=5317) roi_x 128
# (func pid=5317) lr 0.0005
# (func pid=5317) weight_decay 0.0005
# (func pid=5317) warmup_epochs 50
# (func pid=5317) max_epochs 20
# (func pid=5317) cuda is available
# (func pid=5317) model: attention_unet
# (func pid=5317) loss: dice ce loss
# (func pid=5317) optimzer: AdamW
# (func pid=5317) {'lr': 0.0005, 'weight_decay': 0.0005}
# (func pid=5317) load json from /content/CardiacSegV2/exps/data_dicts/chgh/AICUP_training.json
# (func pid=5317) train files (9): ['patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019']
# (func pid=5317) val files (3): ['patient0048', 'patient0049', 'patient0050']
# (func pid=5317) test files (3): ['patient0001', 'patient0002', 'patient0003']
# (func pid=5317)
# (func pid=5317) load train dataset ...
# (func pid=5317) Using MONAI Cache Dataset
# (func pid=5317) /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=5317)   warn_deprecated(argname, msg, warning_category)
# (func pid=5317) /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=5317)   warn_deprecated(obj, msg, warning_category)
# (func pid=5317) /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# (func pid=5317)   warn_deprecated(argname, msg, warning_category)
# Loading dataset:   0%|          | 0/9 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:04:14 (running for 00:00:20.44)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:19 (running for 00:00:25.48)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:24 (running for 00:00:30.54)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  11%|█         | 1/9 [00:13<01:48, 13.53s/it]
# == Status ==
# Current time: 2025-11-16 14:04:29 (running for 00:00:35.57)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  22%|██▏       | 2/9 [00:18<01:00,  8.62s/it]
# == Status ==
# Current time: 2025-11-16 14:04:34 (running for 00:00:40.61)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:39 (running for 00:00:45.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  33%|███▎      | 3/9 [00:29<00:58,  9.78s/it]
# == Status ==
# Current time: 2025-11-16 14:04:44 (running for 00:00:50.69)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  44%|████▍     | 4/9 [00:30<00:31,  6.33s/it]
# == Status ==
# Current time: 2025-11-16 14:04:50 (running for 00:00:55.72)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:04:55 (running for 00:01:00.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  56%|█████▌    | 5/9 [00:43<00:34,  8.59s/it]
# == Status ==
# Current time: 2025-11-16 14:05:00 (running for 00:01:05.78)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  67%|██████▋   | 6/9 [00:49<00:23,  7.72s/it]
# == Status ==
# Current time: 2025-11-16 14:05:05 (running for 00:01:10.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:05:10 (running for 00:01:15.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  78%|███████▊  | 7/9 [00:58<00:16,  8.26s/it]
# == Status ==
# Current time: 2025-11-16 14:05:15 (running for 00:01:20.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  89%|████████▉ | 8/9 [01:01<00:06,  6.33s/it]
# == Status ==
# Current time: 2025-11-16 14:05:20 (running for 00:01:25.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# (func pid=5317)
# (func pid=5317) load val dataset ...
# (func pid=5317) Using MONAI Cache Dataset
# Loading dataset: 100%|██████████| 9/9 [01:09<00:00,  7.75s/it]
# Loading dataset:   0%|          | 0/3 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:05:25 (running for 00:01:30.95)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:05:30 (running for 00:01:35.98)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:05:35 (running for 00:01:41.02)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:05:40 (running for 00:01:46.05)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset:  33%|███▎      | 1/3 [00:16<00:32, 16.36s/it]
# == Status ==
# Current time: 2025-11-16 14:05:45 (running for 00:01:51.08)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# Loading dataset: 100%|██████████| 3/3 [00:25<00:00,  8.66s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:05:50 (running for 00:01:56.12)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:05:55 (running for 00:02:01.14)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (0 Steps) (loss=2.32464):  11%|█         | 1/9 [00:08<01:11,  8.90s/it]
# == Status ==
# Current time: 2025-11-16 14:06:00 (running for 00:02:06.16)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (1 Steps) (loss=2.25472):  22%|██▏       | 2/9 [00:14<00:48,  6.99s/it]
# == Status ==
# Current time: 2025-11-16 14:06:05 (running for 00:02:11.20)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (2 Steps) (loss=2.16780):  33%|███▎      | 3/9 [00:20<00:38,  6.40s/it]
# == Status ==
# Current time: 2025-11-16 14:06:10 (running for 00:02:16.22)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:06:15 (running for 00:02:21.25)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (3 Steps) (loss=2.15588):  44%|████▍     | 4/9 [00:25<00:30,  6.13s/it]
# == Status ==
# Current time: 2025-11-16 14:06:20 (running for 00:02:26.27)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (4 Steps) (loss=1.98665):  56%|█████▌    | 5/9 [00:31<00:23,  6.00s/it]
# == Status ==
# Current time: 2025-11-16 14:06:25 (running for 00:02:31.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (5 Steps) (loss=1.98438):  67%|██████▋   | 6/9 [00:37<00:17,  5.93s/it]
# == Status ==
# Current time: 2025-11-16 14:06:30 (running for 00:02:36.32)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (6 Steps) (loss=1.77044):  78%|███████▊  | 7/9 [00:43<00:11,  5.90s/it]
# == Status ==
# Current time: 2025-11-16 14:06:35 (running for 00:02:41.34)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (7 Steps) (loss=1.85698):  89%|████████▉ | 8/9 [00:49<00:05,  5.90s/it]
# == Status ==
# Current time: 2025-11-16 14:06:40 (running for 00:02:46.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 0] Training (8 Steps) (loss=1.88823): 100%|██████████| 9/9 [00:55<00:00,  5.90s/it]
# [Epoch 0] Training (8 Steps) (loss=1.88823): 100%|██████████| 9/9 [00:55<00:00,  6.14s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:06:45 (running for 00:02:51.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:06:50 (running for 00:02:56.42)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (9 Steps) (loss=2.08620):  11%|█         | 1/9 [00:06<00:54,  6.87s/it]
# == Status ==
# Current time: 2025-11-16 14:06:55 (running for 00:03:01.45)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (10 Steps) (loss=1.92425):  22%|██▏       | 2/9 [00:12<00:44,  6.37s/it]
# == Status ==
# Current time: 2025-11-16 14:07:00 (running for 00:03:06.48)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (11 Steps) (loss=1.94560):  33%|███▎      | 3/9 [00:18<00:37,  6.23s/it]
# == Status ==
# Current time: 2025-11-16 14:07:05 (running for 00:03:11.51)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (12 Steps) (loss=1.75599):  44%|████▍     | 4/9 [00:25<00:30,  6.18s/it]
# == Status ==
# Current time: 2025-11-16 14:07:10 (running for 00:03:16.54)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:07:15 (running for 00:03:21.56)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (13 Steps) (loss=1.87676):  56%|█████▌    | 5/9 [00:31<00:24,  6.17s/it]
# == Status ==
# Current time: 2025-11-16 14:07:20 (running for 00:03:26.59)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (14 Steps) (loss=1.89763):  67%|██████▋   | 6/9 [00:37<00:18,  6.18s/it]
# == Status ==
# Current time: 2025-11-16 14:07:25 (running for 00:03:31.62)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (15 Steps) (loss=1.76053):  78%|███████▊  | 7/9 [00:43<00:12,  6.20s/it]
# == Status ==
# Current time: 2025-11-16 14:07:30 (running for 00:03:36.64)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (16 Steps) (loss=1.78281):  89%|████████▉ | 8/9 [00:49<00:06,  6.20s/it]
# == Status ==
# Current time: 2025-11-16 14:07:35 (running for 00:03:41.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:07:40 (running for 00:03:46.69)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 1] Training (17 Steps) (loss=1.74473): 100%|██████████| 9/9 [00:55<00:00,  6.18s/it]
# [Epoch 1] Training (17 Steps) (loss=1.74473): 100%|██████████| 9/9 [00:56<00:00,  6.23s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:07:46 (running for 00:03:51.71)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (18 Steps) (loss=1.73396):  11%|█         | 1/9 [00:07<00:57,  7.14s/it]
# == Status ==
# Current time: 2025-11-16 14:07:51 (running for 00:03:56.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (19 Steps) (loss=1.72756):  22%|██▏       | 2/9 [00:13<00:45,  6.51s/it]
# == Status ==
# Current time: 2025-11-16 14:07:56 (running for 00:04:01.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (20 Steps) (loss=1.76835):  33%|███▎      | 3/9 [00:19<00:37,  6.30s/it]
# == Status ==
# Current time: 2025-11-16 14:08:01 (running for 00:04:06.79)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:08:06 (running for 00:04:11.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (21 Steps) (loss=1.75155):  44%|████▍     | 4/9 [00:25<00:31,  6.20s/it]
# == Status ==
# Current time: 2025-11-16 14:08:11 (running for 00:04:16.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (22 Steps) (loss=1.65744):  56%|█████▌    | 5/9 [00:31<00:24,  6.15s/it]
# == Status ==
# Current time: 2025-11-16 14:08:16 (running for 00:04:21.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (23 Steps) (loss=1.67002):  67%|██████▋   | 6/9 [00:37<00:18,  6.12s/it]
# == Status ==
# Current time: 2025-11-16 14:08:21 (running for 00:04:26.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (24 Steps) (loss=1.61118):  67%|██████▋   | 6/9 [00:43<00:18,  6.12s/it]
# [Epoch 2] Training (24 Steps) (loss=1.61118):  78%|███████▊  | 7/9 [00:43<00:12,  6.10s/it]
# == Status ==
# Current time: 2025-11-16 14:08:26 (running for 00:04:31.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (25 Steps) (loss=1.80561):  89%|████████▉ | 8/9 [00:49<00:06,  6.09s/it]
# == Status ==
# Current time: 2025-11-16 14:08:31 (running for 00:04:36.95)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# == Status ==
# Current time: 2025-11-16 14:08:36 (running for 00:04:41.97)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# [Epoch 2] Training (26 Steps) (loss=1.80446): 100%|██████████| 9/9 [00:55<00:00,  6.09s/it]
# [Epoch 2] Training (26 Steps) (loss=1.80446): 100%|██████████| 9/9 [00:55<00:00,  6.20s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-11-16 14:08:41 (running for 00:04:46.99)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+
# | Trial name       | status   | loc             | exp                  |
# |------------------+----------+-----------------+----------------------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |
# +------------------+----------+-----------------+----------------------+
#
#
# ...
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:23 (running for 00:27:29.21)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:28 (running for 00:27:34.24)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:33 (running for 00:27:39.27)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# (func pid=5317) Confusion_Vals： [[4.7625600e+05 3.3308900e+05 1.4670437e+07 9.8543000e+04]
# (func pid=5317)  [0.0000000e+00 0.0000000e+00 1.5567919e+07 1.0406000e+04]
# (func pid=5317)  [0.0000000e+00 0.0000000e+00 1.5578325e+07 0.0000000e+00]]
# (func pid=5317) infer test time aug:
# (func pid=5317) dice: [0.6881596 0.              nan]
# (func pid=5317) iou: [0.5245757 0.              nan]
# (func pid=5317) /tmp/ray/session_2025-11-16_14-03-45_999999_4923/runtime_resources/working_dir_files/_ray_pkg_ffdb4ca273214716/runners/inferer.py:98: RuntimeWarning: invalid value encountered in divide
# (func pid=5317)   sensitivity_vals = tp / (tp + fn)
# (func pid=5317) Confusion_Vals： [[3.2041200e+06 2.1120160e+06 9.6551872e+07 6.3029400e+05]
# (func pid=5317)  [0.0000000e+00 0.0000000e+00 1.0243005e+08 6.8256000e+04]
# (func pid=5317)  [0.0000000e+00 0.0000000e+00 1.0249830e+08 0.0000000e+00]]
# (func pid=5317) infer test original:
# (func pid=5317) dice: [0.7003117 0.              nan]
# (func pid=5317) iou: [0.5388305 0.              nan]
# (func pid=5317) sensitivity: [0.83562183 0.                nan]
# (func pid=5317) specificity: [0.9785938 1.        1.       ]
# (func pid=5317) infer data: {'image': '/content/CardiacSegV2/dataset/chgh/patient0003.nii.gz', 'label': '/content/CardiacSegV2/dataset/chgh/patient0003_gt.nii.gz'}
# == Status ==
# Current time: 2025-11-16 14:31:38 (running for 00:27:44.29)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:43 (running for 00:27:49.33)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# (func pid=5317) infer time: 0.04606127738952637 sec
# (func pid=5317) use post process infer
# == Status ==
# Current time: 2025-11-16 14:31:48 (running for 00:27:54.35)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:53 (running for 00:27:59.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:31:58 (running for 00:28:04.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:32:03 (running for 00:28:09.43)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-11-16 14:32:08 (running for 00:28:14.45)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# (func pid=5317) Confusion_Vals： [[4.7936900e+05 2.2979900e+05 1.5639335e+07 1.3677900e+05]
# (func pid=5317)  [0.0000000e+00 1.0000000e+00 1.6472528e+07 1.2753000e+04]
# (func pid=5317)  [0.0000000e+00 0.0000000e+00 1.6485282e+07 0.0000000e+00]]
# (func pid=5317) infer test time aug:
# (func pid=5317) dice: [0.72340333 0.                nan]
# (func pid=5317) iou: [0.56666553 0.                nan]
# == Status ==
# Current time: 2025-11-16 14:32:13 (running for 00:28:19.48)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
# | Trial name       | status   | loc             | exp                  |   tt_dice |   tt_iou |   val_bst_acc |   esc |
# |------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------|
# | main_1625c_00000 | RUNNING  | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |         0 |        0 |      0.511646 |     0 |
# +------------------+----------+-----------------+----------------------+-----------+----------+---------------+-------+
#
#
# (func pid=5317) Confusion_Vals： [[2.492956e+06 1.161600e+06 8.057611e+07 7.039900e+05]
# (func pid=5317)  [0.000000e+00 8.000000e+00 8.486849e+07 6.616100e+04]
# (func pid=5317)  [0.000000e+00 0.000000e+00 8.493466e+07 0.000000e+00]]
# (func pid=5317) infer test original:
# (func pid=5317) dice: [0.727711 0.            nan]
# (func pid=5317) iou: [0.5719699 0.              nan]
# (func pid=5317) sensitivity: [0.77979296 0.                nan]
# (func pid=5317) specificity: [0.9857887 0.9999999 1.       ]
# (func pid=5317)
# (func pid=5317) eval result:
# (func pid=5317) avg tt dice: 0.3118966
# (func pid=5317) avg tt iou: 0.24036211
# (func pid=5317) avg inf dice: 0.31560943
# (func pid=5317) avg inf iou: 0.24475896
# (func pid=5317) avg inf sensitivity: 0.35821614
# (func pid=5317) avg inf specificity: 0.99396825
# (func pid=5317) avg inf time: 0.048489014307657875
# Result for main_1625c_00000:
#   date: 2025-11-16_14-32-15
#   done: false
#   hostname: 5c91bc18d35b
#   inf_dice: 0.3156094253063202
#   inf_iou: 0.2447589635848999
#   inf_time: 0.048489014307657875
#   iterations_since_restore: 5
#   node_ip: 172.30.0.2
#   pid: 5317
#   time_since_restore: 1681.639600276947
#   time_this_iter_s: 115.4971992969513
#   time_total_s: 1681.639600276947
#   timestamp: 1763303535
#   training_iteration: 5
#   trial_id: 1625c_00000
#   tt_dice: 0.31189659237861633
#   tt_iou: 0.24036210775375366
#   val_bst_acc: 0.5116462111473083
#
# Trial main_1625c_00000 completed.
# == Status ==
# Current time: 2025-11-16 14:32:15 (running for 00:28:21.39)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs
# Result logdir: /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training
# Number of trials: 1/1 (1 TERMINATED)
# +------------------+------------+-----------------+----------------------+-----------+----------+------------+-----------+---------------+------------+
# | Trial name       | status     | loc             | exp                  |   tt_dice |   tt_iou |   inf_dice |   inf_iou |   val_bst_acc |   inf_time |
# |------------------+------------+-----------------+----------------------+-----------+----------+------------+-----------+---------------+------------|
# | main_1625c_00000 | TERMINATED | 172.30.0.2:5317 | {'exp': 'AICUP__6940 |  0.311897 | 0.240362 |   0.315609 |  0.244759 |      0.511646 |   0.048489 |
# +------------------+------------+-----------------+----------------------+-----------+----------+------------+-----------+---------------+------------+
#
#
# 2025-11-16 14:32:15,693	INFO tune.py:1111 -- Total run time: 1701.43 seconds (1701.39 seconds for the tuning loop).
# (func pid=5317)      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_iouC  tt_iouAO  tt_iouCA  inf_diceC  inf_diceAO  inf_diceCA  inf_iouC  inf_iouAO  inf_iouCA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA  inf_time
# (func pid=5317) 0  patient0001  0.689725        0.0        0.0  0.526397       0.0       0.0   0.698451         0.0         0.0  0.536630        0.0        0.0          0.800823                0.0                0.0          0.981332                1.0                1.0  0.057761
# (func pid=5317) 1  patient0002  0.688160        0.0        NaN  0.524576       0.0       NaN   0.700312         0.0         NaN  0.538831        0.0        NaN          0.835622                0.0                NaN          0.978594                1.0                1.0  0.041645
# (func pid=5317) 2  patient0003  0.723403        0.0        NaN  0.566666       0.0       NaN   0.727711         0.0         NaN  0.571970        0.0        NaN          0.779793                0.0                NaN          0.985789                1.0                1.0  0.046061

# %% [markdown]
# 測試訓練結果

# %%
! sudo chmod 700 /content/CardiacSegV2/expers/tune.py

# %%
# testing
# !python /content/CardiacSegV2/expers/tune.py \
--tune_mode="test" \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=4 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-42 \
--a_max=423 \
--space_x=0.7 \
--space_y=0.7 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=128 \
--optim="AdamW" \
--lr=5e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
--resume_tuner \
--save_eval_csv \
--test_mode
# Out:
# 2025-11-16 14:34:06.697235: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763303646.734067   14108 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763303646.745882   14108 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-16 14:34:06.778609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# 2025-11-16 14:34:31,799	INFO worker.py:1636 -- Started a local Ray instance.
# 2025-11-16 14:34:32,441	INFO packaging.py:520 -- Creating a file package for local directory '/content/CardiacSegV2'.
# 2025-11-16 14:34:32,473	WARNING packaging.py:394 -- File /content/CardiacSegV2/.git/objects/pack/pack-e31abb332b17f9926c99906971b191c247ca92a0.pack is very large (17.33MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['/content/CardiacSegV2/.git/objects/pack/pack-e31abb332b17f9926c99906971b191c247ca92a0.pack']})`
# 2025-11-16 14:34:33,068	INFO packaging.py:347 -- Pushing file package 'gcs://_ray_pkg_ffdb4ca273214716.zip' (37.60MiB) to Ray cluster...
# 2025-11-16 14:34:33,317	INFO packaging.py:360 -- Successfully pushed file package 'gcs://_ray_pkg_ffdb4ca273214716.zip'.
# test mode
# resume tuner form /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results
# 2025-11-16 14:34:35,347	INFO experiment_analysis.py:966 -- No trial data passed in during `ExperimentAnalysis` initialization -- you are most likely loading the experiment after it has completed.
# Loading trial data from the experiment checkpoint file. This may result in loading some stale information, since checkpointing is periodic.
# run test mode ...
# cuda is available
# model: attention_unet
# loss: dice ce loss
# optimzer: AdamW
# {'lr': 0.0005, 'weight_decay': 0.0005}
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/models/best_model.pth' (epoch 21) (bestacc 0.5116462111473083) (early stop count 0)
# load json from /content/CardiacSegV2/exps/data_dicts/chgh/AICUP_training.json
# train files (9): ['patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019']
# val files (3): ['patient0048', 'patient0049', 'patient0050']
# test files (3): ['patient0001', 'patient0002', 'patient0003']
# infer data: {'image': '/content/CardiacSegV2/dataset/chgh/patient0001.nii.gz', 'label': '/content/CardiacSegV2/dataset/chgh/patient0001_gt.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 22.539217233657837 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# Confusion_Vals： [[4.6147300e+05 2.8622500e+05 1.5046963e+07 1.1261400e+05]
#  [0.0000000e+00 0.0000000e+00 1.5898195e+07 9.0800000e+03]
#  [0.0000000e+00 0.0000000e+00 1.5907189e+07 8.6000000e+01]]
# infer test time aug:
# dice: [0.69825727 0.         0.        ]
# iou: [0.5364019 0.        0.       ]
# Confusion_Vals： [[2.647276e+06 1.572080e+06 8.455327e+07 6.184770e+05]
#  [0.000000e+00 0.000000e+00 8.934023e+07 5.087400e+04]
#  [0.000000e+00 0.000000e+00 8.939064e+07 4.680000e+02]]
# infer test original:
# dice: [0.70734507 0.         0.        ]
# iou: [0.5472033 0.        0.       ]
# sensitivity: [0.8106173 0.        0.       ]
# specificity: [0.9817466 1.        1.       ]
# infer data: {'image': '/content/CardiacSegV2/dataset/chgh/patient0002.nii.gz', 'label': '/content/CardiacSegV2/dataset/chgh/patient0002_gt.nii.gz'}
# infer time: 0.04686856269836426 sec
# use post process infer
# Confusion_Vals： [[4.8459900e+05 3.2912300e+05 1.4674403e+07 9.0200000e+04]
#  [0.0000000e+00 0.0000000e+00 1.5567919e+07 1.0406000e+04]
#  [0.0000000e+00 0.0000000e+00 1.5578325e+07 0.0000000e+00]]
# /content/CardiacSegV2/runners/inferer.py:98: RuntimeWarning: invalid value encountered in divide
#   sensitivity_vals = tp / (tp + fn)
# infer test time aug:
# dice: [0.69800746 0.                nan]
# iou: [0.5361071 0.              nan]
# Confusion_Vals： [[3.2619330e+06 2.0824640e+06 9.6581424e+07 5.7248100e+05]
#  [0.0000000e+00 0.0000000e+00 1.0243005e+08 6.8256000e+04]
#  [0.0000000e+00 0.0000000e+00 1.0249830e+08 0.0000000e+00]]
# infer test original:
# dice: [0.71075237 0.                nan]
# iou: [0.55129236 0.                nan]
# sensitivity: [0.85069925 0.                nan]
# specificity: [0.97889334 1.         1.        ]
# infer data: {'image': '/content/CardiacSegV2/dataset/chgh/patient0003.nii.gz', 'label': '/content/CardiacSegV2/dataset/chgh/patient0003_gt.nii.gz'}
# infer time: 0.04031014442443848 sec
# use post process infer
# Confusion_Vals： [[4.8736800e+05 2.3692300e+05 1.5632211e+07 1.2878000e+05]
#  [0.0000000e+00 1.0000000e+00 1.6472528e+07 1.2753000e+04]
#  [0.0000000e+00 0.0000000e+00 1.6485282e+07 0.0000000e+00]]
# infer test time aug:
# dice: [0.72717667 0.                nan]
# iou: [0.57131 0.          nan]
# Confusion_Vals： [[2.534350e+06 1.197784e+06 8.053993e+07 6.625960e+05]
#  [0.000000e+00 8.000000e+00 8.486849e+07 6.616100e+04]
#  [0.000000e+00 0.000000e+00 8.493466e+07 0.000000e+00]]
# infer test original:
# dice: [0.73151106 0.                nan]
# iou: [0.57667905 0.                nan]
# sensitivity: [0.79274094 0.                nan]
# specificity: [0.985346  0.9999999 1.       ]
#
# eval result:
# avg tt dice: 0.31511483
# avg tt iou: 0.24416973
# avg inf dice: 0.31897113
# avg inf iou: 0.24879558
# avg inf sensitivity: 0.3639753
# avg inf specificity: 0.99399847
# avg inf time: 7.542131980260213
#      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_iouC  tt_iouAO  tt_iouCA  inf_diceC  inf_diceAO  inf_diceCA  inf_iouC  inf_iouAO  inf_iouCA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA   inf_time
# 0  patient0001  0.698257        0.0        0.0  0.536402       0.0       0.0   0.707345         0.0         0.0  0.547203        0.0        0.0          0.810617                0.0                0.0          0.981747                1.0                1.0  22.539217
# 1  patient0002  0.698007        0.0        NaN  0.536107       0.0       NaN   0.710752         0.0         NaN  0.551292        0.0        NaN          0.850699                0.0                NaN          0.978893                1.0                1.0   0.046869
# 2  patient0003  0.727177        0.0        NaN  0.571310       0.0       NaN   0.731511         0.0         NaN  0.576679        0.0        NaN          0.792741                0.0                NaN          0.985346                1.0                1.0   0.040310
# 2025-11-16 14:36:27,097	WARNING session.py:91 -- Session not detected. You should not be calling `report` outside `tuner.fit()` or while using the class API.
# 2025-11-16 14:36:27,097	WARNING session.py:97 --   File "/content/CardiacSegV2/expers/tune.py", line 489, in <module>
#     main_worker(args)
#   File "/content/CardiacSegV2/expers/tune.py", line 359, in main_worker
#     tune.report(

# %% [markdown]
# ![投影片15.PNG](data:image/png;base64,...)

# %% [markdown]
# # 下載權重檔

# %%
# %cd ./CardiacSegV2/exps/exps/attention_unet/chgh/tune_results/
# !zip -r AICUP_training.zip AICUP_training
# Out:
# /content/CardiacSegV2/exps/exps/attention_unet/chgh/tune_results
#   adding: AICUP_training/ (stored 0%)
#   adding: AICUP_training/basic-variant-state-2025-11-16_14-03-54.json (deflated 52%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/ (stored 0%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/params.pkl (deflated 5%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/evals/ (stored 0%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/evals/best_model.csv (deflated 59%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/models/ (stored 0%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/models/best_model.pth (deflated 8%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/models/final_model.pth (deflated 8%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/params.json (deflated 17%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/result.json (deflated 77%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/progress.csv (deflated 60%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/logs/ (stored 0%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/logs/events.out.tfevents.1763303420.5c91bc18d35b.5317.1 (deflated 9%)
#   adding: AICUP_training/main_1625c_00000_0_exp=exp_AICUP_training_2025-11-16_14-03-54/logs/events.out.tfevents.1763301854.5c91bc18d35b.5317.0 (deflated 66%)
#   adding: AICUP_training/experiment_state-2025-11-16_14-03-54.json (deflated 87%)
#   adding: AICUP_training/tuner.pkl (deflated 48%)

# %%
from google.colab import files
files.download("AICUP_training.zip")
